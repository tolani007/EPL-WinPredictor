# %% [markdown]
# <a href="https://colab.research.google.com/github/tolani007/EPL-WinPredictor/blob/main/Brainstation_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # Inspecting my data in panda dataframes:

# %% [markdown]
# # Task
# Load the CSV files "/content/epl 23:24.csv", "/content/epl 24:25 .csv", and "/content/epl 25:26.csv" into separate pandas DataFrames and display the first 5 rows of each.

# %% [markdown]
# ## Load EPL 23:24 Data
#
# ### Subtask:
# Load the '/content/epl 23:24.csv' file into a pandas DataFrame and display the first 5 rows to inspect its content.

# %% [markdown]
# **Reasoning**:
# To load and inspect the data as requested, I need to import the pandas library, read the specified CSV file into a DataFrame, and then display its first 5 rows.

# %%
import pandas as pd
df_22_23 = pd.read_csv('/content/epl_22_23.csv')
df_22_23.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.634211    1.218421    0.757895    0.563158   13.952632   11.310526
# std      1.419944    1.183518    0.918480    0.746998    5.604170    4.941173
# min      0.000000    0.000000    0.000000    0.000000    1.000000    1.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    8.000000
# 50%      1.000000    1.000000    1.000000    0.000000   14.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   17.000000   15.000000
# max      9.000000    6.000000    5.000000    3.000000   33.000000   30.000000
#
#               HST         AST          HF          AF  ...    AvgC<2.5  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     4.907895    3.894737   10.597368   10.931579  ...    2.100605
# ...

# %%
import pandas as pd
df_23_24 = pd.read_csv('/content/epl_23_24.csv')
df_23_24.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.800000    1.478947    0.734211    0.626316   15.402632   12.181579
# std      1.365616    1.277811    0.831687    0.823367    6.261959    5.467696
# min      0.000000    0.000000    0.000000    0.000000    1.000000    2.000000
# 25%      1.000000    1.000000    0.000000    0.000000   11.000000    8.000000
# 50%      2.000000    1.000000    1.000000    0.000000   15.000000   11.000000
# 75%      3.000000    2.000000    1.000000    1.000000   19.000000   15.000000
# max      6.000000    8.000000    4.000000    5.000000   36.000000   30.000000
#
#               HST         AST          HF          AF  ...    AvgC<2.5  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     5.436842    4.431579   10.744737   11.347368  ...    2.441474
# ...

# %%
import pandas as pd
df_24_25 = pd.read_csv('/content/epl_24_25 .csv')
df_24_25.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.513158    1.421053    0.752632    0.610526   13.752632   12.165789
# std      1.277917    1.189922    0.875867    0.828831    5.588045    5.409987
# min      0.000000    0.000000    0.000000    0.000000    2.000000    1.000000
# 25%      1.000000    1.000000    0.000000    0.000000   10.000000    9.000000
# 50%      1.000000    1.000000    1.000000    0.000000   13.000000   11.500000
# 75%      2.000000    2.000000    1.000000    1.000000   17.000000   15.000000
# max      7.000000    6.000000    4.000000    5.000000   36.000000   37.000000
#
#               HST         AST          HF          AF  ...    B365CAHH  \
# count  380.000000  380.000000  380.000000  380.000000  ...  380.000000
# mean     4.834211    4.265789   10.789474   11.276316  ...    1.946421
# ...

# %%
import pandas as pd
df_25_26 = pd.read_csv('/content/epl_25_26.csv')
df_25_26.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  240.000000  240.000000  240.000000  240.000000  240.000000  240.000000
# mean     1.562500    1.225000    0.712500    0.479167   13.375000   11.016667
# std      1.187562    1.101255    0.779342    0.708277    4.939064    4.635651
# min      0.000000    0.000000    0.000000    0.000000    3.000000    3.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    7.000000
# 50%      2.000000    1.000000    1.000000    0.000000   13.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   16.000000   14.000000
# max      5.000000    5.000000    3.000000    3.000000   32.000000   30.000000
#
#               HST         AST          HF          AF  ...    B365CAHH  \
# count  240.000000  240.000000  240.000000  240.000000  ...  240.000000
# mean     4.450000    3.787500   10.470833   10.908333  ...    1.920042
# ...

# %% [markdown]
# ## Load EPL 24:25 Data
#
# ### Subtask:
# Load the '/content/epl 24:25 .csv' file into a pandas DataFrame and display the first 5 rows to inspect its content.

# %% [markdown]
# **Reasoning**:
# Load the '/content/epl 24:25 .csv' file into a pandas DataFrame named `df_24_25` and display its first 5 rows to inspect its content, following the subtask instructions.

# %%
df_24_25 = pd.read_csv('/content/epl 24:25 .csv')
df_24_25.head()
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...     1.86     2.07   1.83   2.11     1.88     2.11     1.82     2.05
# 1  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99     1.88
# 2  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99     1.87
# 3  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83     2.04
# 4  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82     2.05
#
#    BFECAHH  BFECAHA
# 0     1.90     2.08
# ...

# %% [markdown]
# ## Load EPL 25:26 Data
#
# ### Subtask:
# Load the '/content/epl 25:26.csv' file into a pandas DataFrame and display the first 5 rows to inspect its content.

# %% [markdown]
# **Reasoning**:
# Load the '/content/epl 25:26.csv' file into a pandas DataFrame named `df_25_26` and display its first 5 rows to inspect its content, following the subtask instructions.

# %% [markdown]
# **Reasoning**:
# To fulfill the subtask, I will load the specified CSV file into a pandas DataFrame and then display the first 5 rows to inspect its content.

# %%
df_25_26 = pd.read_csv('/content/epl 25:26.csv')
df_25_26.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `epl 23:24.csv` dataset was successfully loaded into a DataFrame (`df_23_24`), containing 5 rows and 106 columns, including match details, full-time/half-time scores, and numerous betting-related statistics. Some betting odds columns showed `NaN` values in the initial rows.
# *   The `epl 24:25 .csv` dataset was successfully loaded into a DataFrame (`df_24_25`), containing similar match details, scores, and various betting odds from different bookmakers.
# *   The `epl 25:26.csv` dataset was successfully loaded into a DataFrame (`df_25_26`), which was observed to contain 132 columns, also encompassing match details and extensive betting-related statistics.
#
# ### Insights or Next Steps
#
# *   The datasets provide comprehensive football match data, including betting odds, which can be valuable for analyzing historical performance, identifying trends, or building predictive models.
# *   The varying number of columns (106 in `df_23_24` versus 132 in `df_25_26`) suggests potential schema evolution across seasons. A crucial next step would be to perform a detailed column-wise comparison and standardization across all three DataFrames to ensure compatibility for combined analysis.
